# %% [markdown]
# # Pandas

# %%
import pandas as pd
import numpy as np

# %%
labels=['A','B','C','D']
sample_list=[10,20,30,40]
array=np.array([1,2,3,4])
dict={'w':100,'x':200,'y':300,'z':400}

# %%
pd.Series(data=sample_list)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
pd.Series(data=sample_list,index=array)
# Out:
# 1    10
# 2    20
# 3    30
# 4    40
# dtype: int64

# %%
pd.Series(array,labels)
# Out:
# A    1
# B    2
# C    3
# D    4
# dtype: int32

# %%
pd.Series(dict)
# Out:
# w    100
# x    200
# y    300
# z    400
# dtype: int64

# %% [markdown]
# ## Pandas dataframe and indexing

# %%
sports1=pd.Series([1,2,3,4,5],index=['Cricket','Football','Basketball','Golf','hockey'])
sports1
# Out:
# Cricket       1
# Football      2
# Basketball    3
# Golf          4
# hockey        5
# dtype: int64

# %%
sports1['Cricket']
# Out:
# 1

# %%
sports1['Football']
# Out:
# 2

# %%
sports2=pd.Series([11,22,33,44],index=['Cricket','Football','Basketball','Golf'])
sports2
# Out:
# Cricket       11
# Football      22
# Basketball    33
# Golf          44
# dtype: int64

# %%
sports1+sports2
# Out:
# Basketball    36.0
# Cricket       12.0
# Football      24.0
# Golf          48.0
# hockey         NaN
# dtype: float64

# %%
df1=pd.DataFrame(np.random.rand(5,5),index='A B C D E'.split(),columns='Score1 Score2 Score3 Score4 Score5'.split())
df1
# Out:
#      Score1    Score2    Score3    Score4    Score5
# A  0.711033  0.376221  0.886853  0.192324  0.621510
# B  0.349476  0.986426  0.610148  0.218209  0.585670
# C  0.079861  0.480738  0.789655  0.201378  0.979708
# D  0.154396  0.376768  0.310629  0.201832  0.029462
# E  0.407637  0.325814  0.898426  0.813511  0.147359

# %%
df1['Score1']
# Out:
# A    0.711033
# B    0.349476
# C    0.079861
# D    0.154396
# E    0.407637
# Name: Score1, dtype: float64

# %%
df1[['Score1','Score2']]
# Out:
#      Score1    Score2
# A  0.711033  0.376221
# B  0.349476  0.986426
# C  0.079861  0.480738
# D  0.154396  0.376768
# E  0.407637  0.325814

# %%
df1['Score6']=df1['Score1']+df1['Score2']

# %%
df1
# Out:
#      Score1    Score2    Score3    Score4    Score5    Score6
# A  0.711033  0.376221  0.886853  0.192324  0.621510  1.087253
# B  0.349476  0.986426  0.610148  0.218209  0.585670  1.335902
# C  0.079861  0.480738  0.789655  0.201378  0.979708  0.560599
# D  0.154396  0.376768  0.310629  0.201832  0.029462  0.531164
# E  0.407637  0.325814  0.898426  0.813511  0.147359  0.733451

# %%
df2={'ID':['A', 'B', 'C', 'D', 'E'],'Name':['Mukund','Vaheed','Sameer','Rahul','Ankit'],'Profit':[20,30,40,50,60]}
df=pd.DataFrame(df2)
df
# Out:
#   ID    Name  Profit
# 0  A  Mukund      20
# 1  B  Vaheed      30
# 2  C  Sameer      40
# 3  D   Rahul      50
# 4  E   Ankit      60

# %%
df["ID"]
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E
# Name: ID, dtype: object

# %%
df[["ID","Name"]]
# Out:
#   ID    Name
# 0  A  Mukund
# 1  B  Vaheed
# 2  C  Sameer
# 3  D   Rahul
# 4  E   Ankit

# %%
df=df.drop("Profit",axis=1)

# %%
df
# Out:
#   ID    Name
# 0  A  Mukund
# 1  B  Vaheed
# 2  C  Sameer
# 3  D   Rahul
# 4  E   Ankit

# %%
df.drop(0)
# Out:
#   ID    Name
# 1  B  Vaheed
# 2  C  Sameer
# 3  D   Rahul
# 4  E   Ankit

# %%
df2={'ID':['101','102','103','104','105'] ,'Name':['John','Manu','Akash','Raja','Jono'],'Profit':[23,78,67,90,25]}
df=pd.DataFrame(df2)
df
# Out:
#     ID   Name  Profit
# 0  101   John      23
# 1  102   Manu      78
# 2  103  Akash      67
# 3  104   Raja      90
# 4  105   Jono      25

# %%
df2={'ID':['1','2','3','4','5'],'Name':['john','mercy','akash','kavi','naina'],'profit': [23,34,54,56,67]}
dg=pd.DataFrame(df2)
dg
# Out:
#   ID   Name  profit
# 0  1   john      23
# 1  2  mercy      34
# 2  3  akash      54
# 3  4   kavi      56
# 4  5  naina      67

# %%
dg['ID']
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: ID, dtype: object

# %%
dg['Name']
# Out:
# 0     john
# 1    mercy
# 2    akash
# 3     kavi
# 4    naina
# Name: Name, dtype: object

# %%
dg.drop("profit",axis=1)
# Out:
#   ID   Name
# 0  1   john
# 1  2  mercy
# 2  3  akash
# 3  4   kavi
# 4  5  naina

# %%
df2={"Subject_Code":['1007','1867','7654','9876','3467'],'subject_name':['English','Marathi','Telagu','Tamil','Gujarati'],'Marks':[198,987,675,765,567]}
df3=pd.DataFrame(df2)
df3
# Out:
#   Subject_Code subject_name  Marks
# 0         1007      English    198
# 1         1867      Marathi    987
# 2         7654       Telagu    675
# 3         9876        Tamil    765
# 4         3467     Gujarati    567

# %% [markdown]
# ### How to import Dataset using Pandas?

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/Premalatha-success/Datasets/main/CardioGoodFitness-1.csv')

# %%
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
df.shape
# Out:
# (180, 9)

# %%
df.head(10)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47
# 5   TM195   20  Female         14     Partnered      3        3   32973     66
# 6   TM195   21  Female         14     Partnered      3        3   35247     75
# 7   TM195   21    Male         13        Single      3        3   32973     85
# 8   TM195   21    Male         15        Single      5        4   35247    141
# 9   TM195   21  Female         15     Partnered      2        3   37521     85

# %%
df.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
df.tail(10)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 170   TM798   31    Male         16     Partnered      6        5   89641
# 171   TM798   33  Female         18     Partnered      4        5   95866
# 172   TM798   34    Male         16        Single      5        5   92131
# 173   TM798   35    Male         16     Partnered      4        5   92131
# 174   TM798   38    Male         18     Partnered      5        5  104581
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 170    260
# 171    200
# 172    150
# 173    360
# 174    150
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
df.sample()
# Out:
#    Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 41   TM195   27  Female         14     Partnered      3        2   45480
#
#     Miles
# 41     66

# %%
df.sample(10)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 103   TM498   25    Male         14     Partnered      4        3   45480
# 56    TM195   31  Female         14        Single      2        2   45480
# 105   TM498   25    Male         16     Partnered      2        3   50028
# 64    TM195   35  Female         16     Partnered      3        3   60261
# 4     TM195   20    Male         13     Partnered      4        2   35247
# 174   TM798   38    Male         18     Partnered      5        5  104581
# 113   TM498   30  Female         14        Single      3        3   57987
# 61    TM195   34    Male         16        Single      4        5   51165
# 34    TM195   26  Female         14     Partnered      3        4   44343
# 78    TM195   47    Male         16     Partnered      4        3   56850
#
#      Miles
# 103    170
# 56      47
# 105     53
# 64      94
# 4       47
# 174    150
# 113     74
# 61     169
# 34     113
# 78      94

# %%
df.shape
# Out:
# (180, 9)

# %%
df.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df.info() #No Missing values in Dataset 180
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
df.describe(include="all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %% [markdown]
# ## Task : Take any DataSet and Work on it

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Premalatha-success/Datasets/main/HousePrices.csv")

# %%
df.head()
# Out:
#    Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 0   1          60         RL         65.0     8450      Pave   NaN
# 1   2          20         RL         80.0     9600      Pave   NaN
# 2   3          60         RL         68.0    11250      Pave   NaN
# 3   4          70         RL         60.0     9550      Pave   NaN
# 4   5          60         RL         84.0    14260      Pave   NaN
#
#   Property_Shape LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature  \
# 0            Reg         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 1            Reg         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 2            IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 3            IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 4            IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold YrSold  SaleType  SaleCondition  Property_Sale_Price
# ...

# %%
df.head(10)
# Out:
#    Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 0   1          60         RL         65.0     8450      Pave   NaN
# 1   2          20         RL         80.0     9600      Pave   NaN
# 2   3          60         RL         68.0    11250      Pave   NaN
# 3   4          70         RL         60.0     9550      Pave   NaN
# 4   5          60         RL         84.0    14260      Pave   NaN
# 5   6          50         RL         85.0    14115      Pave   NaN
# 6   7          20         RL         75.0    10084      Pave   NaN
# 7   8          60         RL          NaN    10382      Pave   NaN
# 8   9          50         RM         51.0     6120      Pave   NaN
# 9  10         190         RL         50.0     7420      Pave   NaN
#
#   Property_Shape LandContour Utilities  ... PoolArea PoolQC  Fence  \
# 0            Reg         Lvl    AllPub  ...        0    NaN    NaN
# 1            Reg         Lvl    AllPub  ...        0    NaN    NaN
# ...

# %%
df.describe()
# Out:
#                 Id   Dwell_Type  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df.describe(include="all")
# Out:
#                  Id   Dwell_Type Zone_Class  LotFrontage        LotArea  \
# count   1460.000000  1460.000000       1460  1201.000000    1460.000000
# unique          NaN          NaN          5          NaN            NaN
# top             NaN          NaN         RL          NaN            NaN
# freq            NaN          NaN       1151          NaN            NaN
# mean     730.500000    56.897260        NaN    70.049958   10516.828082
# std      421.610009    42.300571        NaN    24.284752    9981.264932
# min        1.000000    20.000000        NaN    21.000000    1300.000000
# 25%      365.750000    20.000000        NaN    59.000000    7553.500000
# 50%      730.500000    50.000000        NaN    69.000000    9478.500000
# 75%     1095.250000    70.000000        NaN    80.000000   11601.500000
# max     1460.000000   190.000000        NaN   313.000000  215245.000000
#
#        Road_Type Alley Property_Shape LandContour Utilities  ...     PoolArea  \
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.sample(10)
# Out:
#         Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 1382  1383          70         RM         60.0     7200      Pave   NaN
# 35      36          60         RL        108.0    13418      Pave   NaN
# 665    666          60         RL        106.0    11194      Pave   NaN
# 573    574          80         RL         76.0     9967      Pave   NaN
# 284    285         120         RL         50.0     8012      Pave   NaN
# 435    436          60         RL         43.0    10667      Pave   NaN
# 73      74          20         RL         85.0    10200      Pave   NaN
# 615    616          85         RL         80.0     8800      Pave   NaN
# 1313  1314          60         RL        108.0    14774      Pave   NaN
# 1153  1154          30         RM          NaN     5890      Pave   NaN
#
#      Property_Shape LandContour Utilities  ... PoolArea PoolQC  Fence  \
# 1382            Reg         Lvl    AllPub  ...        0    NaN    NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   1460 non-null   int64
#  1   Dwell_Type           1460 non-null   int64
#  2   Zone_Class           1460 non-null   object
#  3   LotFrontage          1201 non-null   float64
#  4   LotArea              1460 non-null   int64
#  5   Road_Type            1460 non-null   object
#  6   Alley                91 non-null     object
#  7   Property_Shape       1460 non-null   object
#  8   LandContour          1460 non-null   object
#  9   Utilities            1460 non-null   object
#  10  LotConfig            1460 non-null   object
#  11  LandSlope            1460 non-null   object
#  12  Neighborhood         1460 non-null   object
#  13  Condition1           1460 non-null   object
#  14  Condition2           1460 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Id                       0
# Dwell_Type               0
# Zone_Class               0
# LotFrontage            259
# LotArea                  0
#                       ...
# MoSold                   0
# YrSold                   0
# SaleType                 0
# SaleCondition            0
# Property_Sale_Price      0
# Length: 81, dtype: int64

# %%
df.isna().head(10)
# Out:
#       Id  Dwell_Type  Zone_Class  LotFrontage  LotArea  Road_Type  Alley  \
# 0  False       False       False        False    False      False   True
# 1  False       False       False        False    False      False   True
# 2  False       False       False        False    False      False   True
# 3  False       False       False        False    False      False   True
# 4  False       False       False        False    False      False   True
# 5  False       False       False        False    False      False   True
# 6  False       False       False        False    False      False   True
# 7  False       False       False         True    False      False   True
# 8  False       False       False        False    False      False   True
# 9  False       False       False        False    False      False   True
#
#    Property_Shape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# 0           False        False      False  ...     False    True   True
# ...
